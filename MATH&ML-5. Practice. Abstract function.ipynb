# %%
from sympy import symbols, diff, subsets

from scipy import optimize

# %%
def f(x, y):
    return (1 - x) ** 2 + 100 * (y - x ** 2) ** 2
def grad(x, y):
    dx = 2 * x - 2 + 100 * (-4 * y * x + 4 * x ** 3)
    dy = 100 * (2 * y - 2 * x ** 2)
    return (dx, dy)

# %%
x0 = (0, 0)
gamma = 0.001
x_cur = x0

vals = []
coords = []
i = 0
while True:
    x_new = (x_cur[0] - gamma * grad(*x_cur)[0],
            x_cur[1] - gamma * grad(*x_cur)[1])
    if i > 50000:
        break
    x_cur = x_new
    vals.append(f(*x_cur))
    coords.append(x_cur)
    i += 1
    print(f"iter={i}; x=({x_cur[0]:.4f}, {x_cur[1]:.4f});"
          f" f(x)={f(*x_cur):.4f}; grad f(x)=({grad(*x_cur)[0]:.4f}, {grad(*x_cur)[1]:.4f})")

# %%
optimize.minimize(lambda x: f(*x), x0=(0, 0))

# %% [markdown]
# **Задание 8.1**
#
# Найдите минимум функции $2x^2 - 4xy + y^4 + 2 $ с помощью градиентного спуска.

# %%
x, y = symbols('x y')

# %%
def grad_m(x, y):
    dx = 4*x - 4*y
    dy = -4*x + 4*y**3
    return (dx, dy)

# %%
f = 2*x**2 - 4*x*y + y**4 +2
display(diff(f,x))
display(diff(f,y))

# %%
x_0 = (5, 2)
gamma = 0.001
x_cur = x_0

coords = []
i = 0
while True:
    x_new = (x_cur[0] - gamma * grad_m(*x_cur)[0],
            x_cur[1] - gamma * grad_m(*x_cur)[1])
    if i > 50000:
        break
    x_cur = x_new
    coords.append(x_cur)
    i += 1
    # print(f"iter={i}; x=({x_cur[0]:.6f}, {x_cur[1]:.6f}); grad f(x)=({grad_m(*x_cur)[0]:.6f}, {grad_m(*x_cur)[1]:.6f})")

display(f.subs({x: x_cur[0], y: x_cur[1]}))

# %% [markdown]
# **Задание 8.2**
#
# Найдите минимум функции $x^3-2x^2+y^2+z^2-2xy+xz-yz+3z$ с помощью градиентного спуска.

# %%
x, y, z = symbols('x y z')
f_8_2 = x**3-2*x**2+y**2+z**2-2*x*y+x*z-y*z+3*z
display(f_8_2)
display(diff(f_8_2,x))
display(diff(f_8_2,y))
display(diff(f_8_2,z))
# Out:
# x**3 - 2*x**2 - 2*x*y + x*z + y**2 - y*z + z**2 + 3*z
# 3*x**2 - 4*x - 2*y + z
# -2*x + 2*y - z
# x - y + 2*z + 3

# %%
def grad_8_2(x, y, z):
    dx = 3*x**2-4*x-2*y+z
    dy = -2*x+2*y-z
    dz = x-y+2*z+3
    return (dx, dy, dz)

# %%
x_0 = (1, 0, 0)
gamma = 0.1
x_cur = x_0

coords = []
i = 0
while True:
    x_new = (x_cur[0] - gamma * grad_8_2(*x_cur)[0],
            x_cur[1] - gamma * grad_8_2(*x_cur)[1],
            x_cur[2] - gamma * grad_8_2(*x_cur)[2])
    if i > 5000:
        break
    x_cur = x_new
    coords.append(x_cur)
    i += 1
    print(f"iter={i}; grad f(x)=({grad_8_2(*x_cur)[0]:.6f}, {grad_8_2(*x_cur)[1]:.6f}, {grad_8_2(*x_cur)[2]:.6f})")

print(round(x_cur[0]), round(x_cur[1]), round(x_cur[2]), end='')
display(f_8_2)
display(round(f_8_2.subs({x: x_cur[0], y: x_cur[1], z: x_cur[2]})))
# Out:
# iter=1; grad f(x)=(-1.570000, -1.400000, 3.100000)
# iter=2; grad f(x)=(-1.677853, -1.124000, 2.497000)
# iter=3; grad f(x)=(-1.473602, -0.985071, 2.052985)
# iter=4; grad f(x)=(-1.140470, -0.877478, 1.691241)
# iter=5; grad f(x)=(-0.826467, -0.760953, 1.379292)
# iter=6; grad f(x)=(-0.590533, -0.636126, 1.109985)
# iter=7; grad f(x)=(-0.427773, -0.516009, 0.883429)
# iter=8; grad f(x)=(-0.315783, -0.410019, 0.697920)
# iter=9; grad f(x)=(-0.236465, -0.321380, 0.548912)
# iter=10; grad f(x)=(-0.178652, -0.249506, 0.430638)
# iter=11; grad f(x)=(-0.135681, -0.192271, 0.337425)
# iter=12; grad f(x)=(-0.103359, -0.147211, 0.264281)
# iter=13; grad f(x)=(-0.078868, -0.112012, 0.207040)
# iter=14; grad f(x)=(-0.060224, -0.084679, 0.162317)
# iter=15; grad f(x)=(-0.045987, -0.063556, 0.127408)
# iter=16; grad f(x)=(-0.035095, -0.047302, 0.100170)
# iter=17; grad f(x)=(-0.026750, -0.034843, 0.078915)
# iter=18; grad f(x)=(-0.020354, -0.025333, 0.062323)
# ...
